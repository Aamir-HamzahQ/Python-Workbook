# %% [markdown]
# <a href="https://colab.research.google.com/github/Aamir-HamzahQ/Python-Workbook/blob/main/Week_6_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 6
# ## Day 1

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("My dad's favorite car is Land Rover")
# Out:
# My dad's favorite car is Land Rover

# %%
print(3.14)
# Out:
# 3.14

# %%
print("3.14")
# Out:
# 3.14

# %%
print(type("3.14"))
print(type(3.14))
# Out:
# <class 'str'>
# <class 'float'>

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.

# %%
print("This is my first time learning any programming language.\nI am excited because Python is very popular programming language.")
# Out:
# This is my first time learning any programming language.
# I am excited because Python is very popular programming language.

# %%
print('She said: "Python is fun!"')
# Out:
# She said: "Python is fun!"

# %%
print(1,2,3) #multiple argument

print("1"+"2"+"3") #concat operator

print(1 + 2 + 3) # addition operator
# Out:
# 1 2 3
# 123
# 6

# %%
print(13 // 4)
# floor division
# Out:
# 3

# %%
# how many hours are there in 435 minutes?
print(435 // 60)
# Out:
# 7

# %%
print("435 min is", 435//60, "hours and", 435%60, "minutes.")
# Out:
# 435 min is 7 hours and 15 minutes.

# %%
my_age = 33

your_age = 30

my_age = your_age

print(my_age)
# Out:
# 30
